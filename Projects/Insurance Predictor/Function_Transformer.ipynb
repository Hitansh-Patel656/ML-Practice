# %%
import pandas as pd
import numpy as np

import scipy.stats as stats


import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression


from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3,ax4) = plt.subplots(ncols=4, figsize=(50, 12))

ax1.scatter(df['age'], df['charges'],s=5)
ax1.set_title("age")
ax2.scatter(df['bmi'], df['charges'],s=5)
ax2.set_title("bmi")
ax3.scatter(df['children'], df['charges'], s=5)
ax3.set_title("children")
ax4.scatter(df['age'], df['bmi'], s=5)
ax4.set_title("age-bmi")

plt.show()

# %%
df_new=df.drop(columns=['sex','children', 'smoker', 'region', 'charges'])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = []

for i in range(df_new.shape[1]):
    vif.append(variance_inflation_factor(df_new, i))

# %%
pd.DataFrame({'vif': vif}, index=df_new.columns[0:3]).T
# Out:
#           age       bmi
# vif  7.457006  7.457006

# %%
df = pd.get_dummies(df,columns=['sex','smoker','region'], drop_first=True, dtype=int)
df.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
y = df['charges']
X = df.drop('charges', axis=1)


X.head()
# Out:
#    age     bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0         0           1                 0
# 1   18  33.770         1         1           0                 0
# 2   28  33.000         3         1           0                 0
# 3   33  22.705         0         1           0                 1
# 4   32  28.880         0         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#      age     bmi  children  sex_male  smoker_yes  region_northwest  \
# 882   21  22.135         0         0           0                 0
# 505   37  30.875         3         1           0                 1
# 798   58  33.100         0         0           0                 0
# 792   22  23.180         0         0           0                 0
# 201   48  32.230         1         0           0                 0
#
#      region_southeast  region_southwest
# 882                 0                 0
# 505                 0                 0
# 798                 0                 1
# 792                 0                 0
# 201                 1                 0

# %%
X_test.head()
# Out:
#       age     bmi  children  sex_male  smoker_yes  region_northwest  \
# 17     23  23.845         0         1           0                 0
# 1091   55  29.830         0         0           0                 0
# 273    50  27.455         1         1           0                 0
# 270    18  29.370         1         1           0                 0
# 874    44  21.850         3         1           0                 0
#
#       region_southeast  region_southwest
# 17                   0                 0
# 1091                 0                 0
# 273                  0                 0
# 270                  1                 0
# 874                  0                 0

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

r2_score(y_test, y_pred)
# Out:
# 0.7449415564623687

# %%
np.mean(cross_val_score(lr,X_train,y_train , cv=10,scoring='r2'))
# Out:
# np.float64(0.7351679697590502)

# %%
# Plotting the distplots without any transformation

for col in X_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)

    plt.subplot(122)
    stats.probplot(X_train[col], dist="norm", plot=plt)
    plt.title(col)

    plt.show()
# Out:
# C:\Users\baps\AppData\Local\Temp\ipykernel_12860\1268627929.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# C:\Users\baps\AppData\Local\Temp\ipykernel_12860\1268627929.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# ...

# %%
# Apply Yeo-Johnson transform

pt1 = PowerTransformer()

X_train_transformed2 = pt1.fit_transform(X_train)
X_test_transformed2 = pt1.transform(X_test)

lr = LinearRegression()
lr.fit(X_train_transformed2,y_train)

y_pred3 = lr.predict(X_test_transformed2)

print(r2_score(y_test,y_pred3))

pd.DataFrame({'cols':X_train.columns,'Yeo_Johnson_lambdas':pt1.lambdas_})
# Out:
# 0.742925198745368
#                cols  Yeo_Johnson_lambdas
# 0               age             0.683044
# 1               bmi             0.477119
# 2          children            -0.303072
# 3          sex_male             0.161831
# 4        smoker_yes            -6.737343
# 5  region_northwest            -5.514524
# 6  region_southeast            -4.514057
# 7  region_southwest            -5.339817

# %%
# applying cross val score

pt = PowerTransformer()
X_transformed2 = pt.fit_transform(X)

lr = LinearRegression()
np.mean(cross_val_score(lr,X_transformed2,y,scoring='r2'))
# Out:
# np.float64(0.7452026476651951)

# %%
X_train_transformed2 = pd.DataFrame(X_train_transformed2,columns=X_train.columns)

# %%
# Before and after comparision for Yeo-Johnson

for col in X_train_transformed2.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)

    plt.subplot(122)
    sns.distplot(X_train_transformed2[col])
    plt.title(col)

    plt.show()
# Out:
# C:\Users\baps\AppData\Local\Temp\ipykernel_12860\1516575210.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# C:\Users\baps\AppData\Local\Temp\ipykernel_12860\1516575210.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
